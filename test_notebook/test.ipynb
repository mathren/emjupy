# %% [markdown]
# # TEST `emjupy`
# this notebook runs on a remote server on port `9999` with (on remote host)
# ```jupyter-notebook --port 9999 --no-browser```
# I make an `ssh` tunnel running (locally):
# ``` ssh -L 9999:localhost:9999 remote```
# and then connect with `M-x emjupy-login` in emacs.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Show output highlight

# %%
print("output line")
np.log(0)	#	 warning
print(error)
# Out:
# output line
# /tmp/ipykernel_87633/2602761639.py:2: RuntimeWarning: divide by zero encountered in log
#   np.log(0)	#	 warning
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 print("output line")
#       2 np.log(0)	#	 warning
# ----> 3 print(error)
#
# NameError: name 'error' is not defined

# %%
# images are white background
x = np.linspace(-10,10,100)
fig, ax = plt.subplots(figsize=(5,2))
ax.set_xlabel("x")
ax.set_ylabel("y")
p = ax.plot(x, x**2, label="parabola") # assign to var to prevent line of text output
